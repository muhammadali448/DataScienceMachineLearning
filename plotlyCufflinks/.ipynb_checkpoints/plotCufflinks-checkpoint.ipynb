# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import cufflinks as cf
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
print(__version__)
# Out:
# 3.10.0

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# data
df = pd.DataFrame(np.random.randn(100, 4), columns="a b c d".split())

# %%
df.head()
# Out:
#           a         b         c         d
# 0 -0.639322 -0.210168 -2.557573 -0.263341
# 1  0.405470  1.915948 -0.205472  0.215716
# 2 -0.705652  0.461542  1.085514  0.431394
# 3 -0.985648 -0.529231 -1.913525  0.775666
# 4  0.968921  1.495853  0.226083 -0.064057

# %%
df2 = pd.DataFrame({ "Category": ["a", "b", "c"], "Values": [20, 30, 40] })

# %%
df2
# Out:
#   Category  Values
# 0        a      20
# 1        b      30
# 2        c      40

# %%
df.plot()

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="e749f5e9-a1ee-4bad-a398-8670878751bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e749f5e9-a1ee-4bad-a398-8670878751bc")) {
#                     Plotly.newPlot(
#                         'e749f5e9-a1ee-4bad-a398-8670878751bc',
# ...

# %%
# df.iplot(kind="scatter", x="a", y="b")
df.iplot(kind="scatter", x="a", y="b", mode="markers", size=20)
# Out:
# <div>
#
#
#             <div id="6a61afa1-5ed2-4287-812f-2bfad4934f52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6a61afa1-5ed2-4287-812f-2bfad4934f52")) {
#                     Plotly.newPlot(
#                         '6a61afa1-5ed2-4287-812f-2bfad4934f52',
# ...

# %%
df2.iplot(kind="bar", x="Category", y="Values")
# Out:
# <div>
#
#
#             <div id="ec4b7889-30d6-45a7-a925-6f982bb4138d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ec4b7889-30d6-45a7-a925-6f982bb4138d")) {
#                     Plotly.newPlot(
#                         'ec4b7889-30d6-45a7-a925-6f982bb4138d',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "uid": "a2103c28-c7cc-48e4-af11-c0c43582e30a", "x": ["a", "b", "c"], "y": [20, 30, 40]}],
# ...

# %%
# df.head()
# df.iplot(kind="bar")
# df.groupby(by="a").mean().iplot(kind="bar")
# df.count().iplot(kind="bar")
df.sum().iplot(kind="bar")
# Out:
# <div>
#
#
#             <div id="7f78a884-319b-47e7-b3c4-a22460a61898" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7f78a884-319b-47e7-b3c4-a22460a61898")) {
#                     Plotly.newPlot(
#                         '7f78a884-319b-47e7-b3c4-a22460a61898',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "58b54f98-3b1a-41e9-94e3-762b5edf6f19", "x": ["a", "b", "c", "d"], "y": [-17.865028251838115, 3.5799983140805005, -9.07077106152607, 9.611709773098536]}],
# ...

# %%
# df.iplot(kind="box")
df[["a", "b"]].iplot(kind="box")
# Out:
# <div>
#
#
#             <div id="59cce1b9-8352-451c-bcf9-ea5afd314d1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("59cce1b9-8352-451c-bcf9-ea5afd314d1a")) {
#                     Plotly.newPlot(
#                         '59cce1b9-8352-451c-bcf9-ea5afd314d1a',
# ...

# %%
# df3 = pd.DataFrame({ "x": [1, 2, 3, 4, 5], "y": [10, 20, 30, 40, 30], "z": [400, 500, 200, 300, 250] })
df3 = pd.DataFrame({ "x": [1, 2, 3, 4, 5], "y": [10, 20, 30, 40, 30], "z": [5, 4, 3, 2, 1] })

# %%
df3.iplot(kind="surface", colorscale="Blues")
# Out:
# <div>
#
#
#             <div id="09f179d0-ea41-4739-90ad-c061a8ab7258" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("09f179d0-ea41-4739-90ad-c061a8ab7258")) {
#                     Plotly.newPlot(
#                         '09f179d0-ea41-4739-90ad-c061a8ab7258',
# ...

# %%
df["a"].iplot(kind="hist", bins=50)
# Out:
# <div>
#
#
#             <div id="603c0a17-184a-4590-a70e-f01403c969e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("603c0a17-184a-4590-a70e-f01403c969e6")) {
#                     Plotly.newPlot(
#                         '603c0a17-184a-4590-a70e-f01403c969e6',
# ...

# %%
df[["a", "b"]].iplot(kind="spread")
# Out:
# <div>
#
#
#             <div id="1bbf5d33-9467-433d-80dc-40dd3bfd4587" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1bbf5d33-9467-433d-80dc-40dd3bfd4587")) {
#                     Plotly.newPlot(
#                         '1bbf5d33-9467-433d-80dc-40dd3bfd4587',
# ...

# %%
df.iplot(kind="bubble", x="a", y="b", size="c")
# Out:
# <div>
#
#
#             <div id="16b733cc-9af8-4e37-bd60-91506082910f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("16b733cc-9af8-4e37-bd60-91506082910f")) {
#                     Plotly.newPlot(
#                         '16b733cc-9af8-4e37-bd60-91506082910f',
# ...

# %%
# df.scatter_matrix() not working
