# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

# %%
df_1 = pd.read_csv("df1", index_col=0)

# %%
df_1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df_2 = pd.read_csv("df2")

# %%
df_2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# histogram of col A df_1
df_1["A"].hist(bins=30)

# %%
# df_1["A"].plot(kind="hist")
df_1["A"].plot.hist()

# %%
df_2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df_2.plot.area(alpha=0.5)

# %%
df_2.plot.bar(stacked=True)

# %%
df_1.reset_index().plot.line(x="index", y="B", figsize=(12, 3), lw=2)

# %%
# df_1.plot.scatter(x="A", y="B", c="C", cmap="coolwarm")
df_1.plot.scatter(x="A", y="B", s=df_1["C"] * 100, cmap="coolwarm")

# %%
df_1.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])

# %%
df.head()
# Out:
#           a         b
# 0  1.515125  0.005301
# 1  0.345669  0.495758
# 2  0.560947 -0.116041
# 3  1.318219  0.327054
# 4 -0.655753  0.635660

# %%
# df.plot.hexbin(x="a", y="b")
df.plot.hexbin(x="a", y="b", gridsize=25)

# %%
df["a"].plot.kde()

# %%
df["a"].plot.density()

# %%
df.plot.density()
